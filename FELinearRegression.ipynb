# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (11.7, 11.3)
plt.rcParams.update({'font.size': 20})
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.3)})
from datetime import datetime
from sklearn.linear_model import LinearRegression
import time

# %%
Questions = pd.read_csv('FEQuestions.csv')

# %%
Questions.head(2)
# Out:
#    QID  QuestionUserId    QuestionCreateDate  QuestionScore  \
# 0  469           147.0  2008-08-02T15:11:16Z             21
# 1  502           147.0  2008-08-02T17:01:58Z             27
#
#                                        QuestionTitle  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
#
#                                         QuestionBody  NumAnswers  \
# 0  <p>I am using the Photoshop's javascript API t...         4.0
# 1  <p>I have a cross-platform (Python) applicatio...         3.0
#
#                                 QuestionTitleAndBody CodeText  \
# 0  How can I find the full path to a font from it...      NaN
# 1  Get a preview JPEG of a PDF on Windows? <p>I h...      NaN
#
#                                   TagFreeNonCodeText         ...          \
# 0  How can I find the full path to a font from it...         ...
# 1  Get a preview JPEG of a PDF on Windows? I have...         ...
#
#   HasHyperlink HasEmbedImage  HasTried  \
# 0        False         False     False
# 1        False         False     False
#
#                                       Tags  NumTags  HasTagsInTop49  \
# 0  ['python', 'osx', 'fonts', 'photoshop']        4            True
# 1    ['python', 'windows', 'image', 'pdf']        4            True
#
#    QuestionLength  QuestionCodeLength  QuestionTitleLength QuestionPercentCode
# 0             721                   2                   17            0.002766
# 1             367                   2                    9            0.005420
#
# [2 rows x 26 columns]

# %%
print(Questions.isnull().sum())
# Out:
# QID                                  0
# QuestionUserId                    6212
# QuestionCreateDate                   0
# QuestionScore                        0
# QuestionTitle                        0
# QuestionBody                         0
# NumAnswers                           0
# QuestionTitleAndBody                 0
# CodeText                        408555
# TagFreeNonCodeText                   0
# CodeTextLemmatized                   0
# TagFreeNonCodeTextLemmatized         0
# HasError                             0
# HasTraceback                         0
# HasMultiLineCode                     0
# HasBlockCode                         0
# HasHyperlink                         0
# HasEmbedImage                        0
# HasTried                             0
# Tags                                 0
# NumTags                              0
# HasTagsInTop49                       0
# QuestionLength                       0
# QuestionCodeLength                   0
# QuestionTitleLength                  0
# QuestionPercentCode                  0
# dtype: int64

# %%
Questions['QuestionUserId'].fillna(0.0, inplace=True)
Questions['QuestionCreateDate'] = pd.to_datetime(Questions['QuestionCreateDate'])

# %%
Y = Questions.set_index('QID')[['NumAnswers']]

# %%
Y.head()
# Out:
#      NumAnswers
# QID
# 469         4.0
# 502         3.0
# 535         7.0
# 594         3.0
# 683         8.0

# %%
X = Questions.set_index('QID').drop(['Tags', 'QuestionTitle', 'QuestionBody', 'QuestionScore', 'NumAnswers', 'QuestionTitleAndBody', 'CodeText', 'TagFreeNonCodeText', 'CodeTextLemmatized', 'TagFreeNonCodeTextLemmatized'], axis=1, inplace=False)

# %%
X.head()
# Out:
#      QuestionUserId  QuestionCreateDate  HasError  HasTraceback  \
# QID
# 469           147.0 2008-08-02 15:11:16     False         False
# 502           147.0 2008-08-02 17:01:58     False         False
# 535           154.0 2008-08-02 18:43:54     False         False
# 594           116.0 2008-08-03 01:15:08     False         False
# 683           199.0 2008-08-03 13:19:16     False         False
#
#      HasMultiLineCode  HasBlockCode  HasHyperlink  HasEmbedImage  HasTried  \
# QID
# 469             False         False         False          False     False
# 502             False         False         False          False     False
# 535             False         False         False          False     False
# 594             False         False         False          False     False
# 683             False          True         False          False     False
#
#      NumTags  HasTagsInTop49  QuestionLength  QuestionCodeLength  \
# QID
# 469        4            True             721                   2
# 502        4            True             367                   2
# 535        3           False             963                   2
# 594        5           False             201                   2
# 683        3            True             422                  78
#
#      QuestionTitleLength  QuestionPercentCode
# QID
# 469                   17             0.002766
# 502                    9             0.005420
# 535                    7             0.002073
# 594                    9             0.009852
# 683                   12             0.156000

# %%
X.columns
# Out:
# Index(['QuestionUserId', 'QuestionCreateDate', 'HasError', 'HasTraceback',
#        'HasMultiLineCode', 'HasBlockCode', 'HasHyperlink', 'HasEmbedImage',
#        'HasTried', 'NumTags', 'HasTagsInTop49', 'QuestionLength',
#        'QuestionCodeLength', 'QuestionTitleLength', 'QuestionPercentCode'],
#       dtype='object')

# %% [markdown]
# Create 1-hot encoding for cyclic variables.

# %%
X['QuestionCreateDay'] = X['QuestionCreateDate'].dt.day

# %%
X['QuestionCreateMonth'] = X['QuestionCreateDate'].dt.month

# %%
X['QuestionCreateYear'] = X['QuestionCreateDate'].dt.year

# %%
X['QuestionCreateDayOfWeek'] = X['QuestionCreateDate'].dt.dayofweek

# %%
X['QuestionCreateHourOfDay'] = X['QuestionCreateDate'].dt.hour

# %%
X.columns
# Out:
# Index(['QuestionUserId', 'QuestionCreateDate', 'HasError', 'HasTraceback',
#        'HasMultiLineCode', 'HasBlockCode', 'HasHyperlink', 'HasEmbedImage',
#        'HasTried', 'NumTags', 'HasTagsInTop49', 'QuestionLength',
#        'QuestionCodeLength', 'QuestionTitleLength', 'QuestionPercentCode',
#        'QuestionCreateDay', 'QuestionCreateMonth', 'QuestionCreateYear',
#        'QuestionCreateDayOfWeek', 'QuestionCreateHourOfDay'],
#       dtype='object')

# %%
X_dummies = pd.get_dummies(X, columns=['QuestionCreateMonth', 'QuestionCreateDay', 'QuestionCreateDayOfWeek', 'QuestionCreateHourOfDay']).drop('QuestionCreateDate', axis=1)

# %%
X_dummies.head()
# Out:
#      QuestionUserId  HasError  HasTraceback  HasMultiLineCode  HasBlockCode  \
# QID
# 469           147.0     False         False             False         False
# 502           147.0     False         False             False         False
# 535           154.0     False         False             False         False
# 594           116.0     False         False             False         False
# 683           199.0     False         False             False          True
#
#      HasHyperlink  HasEmbedImage  HasTried  NumTags  HasTagsInTop49  \
# QID
# 469         False          False     False        4            True
# 502         False          False     False        4            True
# 535         False          False     False        3           False
# 594         False          False     False        5           False
# 683         False          False     False        3            True
#
#                 ...              QuestionCreateHourOfDay_14  \
# QID             ...
# 469             ...                                       0
# 502             ...                                       0
# 535             ...                                       0
# 594             ...                                       0
# 683             ...                                       0
#
#      QuestionCreateHourOfDay_15  QuestionCreateHourOfDay_16  \
# QID
# 469                           1                           0
# 502                           0                           0
# 535                           0                           0
# 594                           0                           0
# 683                           0                           0
#
#      QuestionCreateHourOfDay_17  QuestionCreateHourOfDay_18  \
# QID
# 469                           0                           0
# 502                           1                           0
# 535                           0                           1
# 594                           0                           0
# 683                           0                           0
#
#      QuestionCreateHourOfDay_19  QuestionCreateHourOfDay_20  \
# QID
# 469                           0                           0
# 502                           0                           0
# 535                           0                           0
# 594                           0                           0
# 683                           0                           0
#
#      QuestionCreateHourOfDay_21  QuestionCreateHourOfDay_22  \
# QID
# 469                           0                           0
# 502                           0                           0
# 535                           0                           0
# 594                           0                           0
# 683                           0                           0
#
#      QuestionCreateHourOfDay_23
# QID
# 469                           0
# 502                           0
# 535                           0
# 594                           0
# 683                           0
#
# [5 rows x 89 columns]

# %%
model = LinearRegression()
model.fit(X_dummies, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
training_accuracy = model.score(X_dummies, Y)
print("Training R^2: ", training_accuracy)
# Out:
# Training R^2:  0.1380583738511627

# %%
pd.options.display.max_rows = 999

# %%
coeffs = pd.DataFrame(data=[X_dummies.columns, model.coef_.squeeze()]).T
coeffs.columns = ['Feature', 'Coeff']
coeffs.sort_values('Coeff', ascending=False)
# Out:
#                        Feature        Coeff
# 6                HasEmbedImage      59734.4
# 15       QuestionCreateMonth_1      54017.7
# 16       QuestionCreateMonth_2      54017.7
# 17       QuestionCreateMonth_3      54017.6
# 18       QuestionCreateMonth_4      54017.6
# 19       QuestionCreateMonth_5      54017.6
# 20       QuestionCreateMonth_6      54017.5
# 21       QuestionCreateMonth_7      54017.5
# 22       QuestionCreateMonth_8      54017.5
# 23       QuestionCreateMonth_9      54017.5
# 24      QuestionCreateMonth_10      54017.5
# 25      QuestionCreateMonth_11      54017.4
# 26      QuestionCreateMonth_12      54017.4
# 29         QuestionCreateDay_3      4042.27
# 43        QuestionCreateDay_17      4042.26
# 27         QuestionCreateDay_1      4042.26
# 38        QuestionCreateDay_12      4042.26
# 36        QuestionCreateDay_10      4042.26
# 39        QuestionCreateDay_13      4042.26
# 41        QuestionCreateDay_15      4042.26
# 37        QuestionCreateDay_11      4042.26
# 34         QuestionCreateDay_8      4042.25
# 49        QuestionCreateDay_23      4042.25
# 54        QuestionCreateDay_28      4042.25
# 42        QuestionCreateDay_16      4042.24
# 56        QuestionCreateDay_30      4042.24
# 33         QuestionCreateDay_7      4042.24
# 28         QuestionCreateDay_2      4042.24
# 45        QuestionCreateDay_19      4042.24
# 32         QuestionCreateDay_6      4042.24
# 51        QuestionCreateDay_25      4042.24
# 35         QuestionCreateDay_9      4042.24
# 57        QuestionCreateDay_31      4042.24
# 48        QuestionCreateDay_22      4042.24
# 31         QuestionCreateDay_5      4042.24
# 30         QuestionCreateDay_4      4042.24
# 44        QuestionCreateDay_18      4042.23
# 47        QuestionCreateDay_21      4042.23
# 52        QuestionCreateDay_26      4042.23
# 50        QuestionCreateDay_24      4042.23
# 40        QuestionCreateDay_14      4042.23
# 53        QuestionCreateDay_27      4042.23
# 55        QuestionCreateDay_29      4042.23
# 46        QuestionCreateDay_20      4042.22
# 13         QuestionPercentCode       3.0108
# 3             HasMultiLineCode     0.119825
# 9               HasTagsInTop49    0.0894496
# 4                 HasBlockCode    0.0823841
# 12         QuestionTitleLength    0.0110025
# 0               QuestionUserId  6.08268e-08
# 10              QuestionLength -6.11742e-05
# 7                     HasTried  -0.00165507
# 11          QuestionCodeLength  -0.00166952
# 1                     HasError   -0.0731561
# 2                 HasTraceback   -0.0751301
# 8                      NumTags    -0.104407
# 14          QuestionCreateYear     -0.29545
# 65   QuestionCreateHourOfDay_0     -5984.68
# 69   QuestionCreateHourOfDay_4     -5984.68
# 84  QuestionCreateHourOfDay_19     -5984.68
# 88  QuestionCreateHourOfDay_23     -5984.69
# 86  QuestionCreateHourOfDay_21     -5984.69
# 70   QuestionCreateHourOfDay_5     -5984.69
# 83  QuestionCreateHourOfDay_18     -5984.69
# 85  QuestionCreateHourOfDay_20     -5984.69
# 71   QuestionCreateHourOfDay_6      -5984.7
# 67   QuestionCreateHourOfDay_2      -5984.7
# 87  QuestionCreateHourOfDay_22      -5984.7
# 82  QuestionCreateHourOfDay_17      -5984.7
# 66   QuestionCreateHourOfDay_1      -5984.7
# 68   QuestionCreateHourOfDay_3      -5984.7
# 78  QuestionCreateHourOfDay_13     -5984.71
# 72   QuestionCreateHourOfDay_7     -5984.72
# 79  QuestionCreateHourOfDay_14     -5984.72
# 77  QuestionCreateHourOfDay_12     -5984.72
# 81  QuestionCreateHourOfDay_16     -5984.72
# 80  QuestionCreateHourOfDay_15     -5984.72
# 73   QuestionCreateHourOfDay_8     -5984.73
# 76  QuestionCreateHourOfDay_11     -5984.74
# 74   QuestionCreateHourOfDay_9     -5984.75
# 75  QuestionCreateHourOfDay_10     -5984.76
# 62   QuestionCreateDayOfWeek_4     -17103.4
# 61   QuestionCreateDayOfWeek_3     -17103.4
# 59   QuestionCreateDayOfWeek_1     -17103.4
# 60   QuestionCreateDayOfWeek_2     -17103.4
# 64   QuestionCreateDayOfWeek_6     -17103.4
# 58   QuestionCreateDayOfWeek_0     -17103.4
# 63   QuestionCreateDayOfWeek_5     -17103.4
# 5                 HasHyperlink     -59734.5

# %% [markdown]
# Based on these coefficients, none of the time features make much of an impact.

# %%
X_nodummy = Questions.set_index('QID').drop(['Tags', 'QuestionTitle', 'QuestionBody', 'QuestionScore', 'NumAnswers', 'QuestionTitleAndBody', 'CodeText', 'TagFreeNonCodeText', 'CodeTextLemmatized', 'TagFreeNonCodeTextLemmatized'], axis=1, inplace=False)

# %%
X_nodummy['QuestionCreateDate'] = X_nodummy['QuestionCreateDate'].apply(lambda x: (x-datetime(1970,1,1)).total_seconds())

# %%
model_nodummy = LinearRegression()
model_nodummy.fit(X_nodummy, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
training_accuracy = model_nodummy.score(X_nodummy, Y)
print("Training R^2: ", training_accuracy)
# Out:
# Training R^2:  0.13756542410345773

# %%
coeffs = pd.DataFrame(data=[X_nodummy.columns, model_nodummy.coef_.squeeze()]).T
coeffs.columns = ['Feature', 'Coeff']
coeffs.sort_values('Coeff', ascending=False)
# Out:
#                 Feature        Coeff
# 14  QuestionPercentCode      2.99256
# 4      HasMultiLineCode     0.119578
# 10       HasTagsInTop49    0.0894647
# 5          HasBlockCode    0.0825569
# 13  QuestionTitleLength    0.0111346
# 0        QuestionUserId  6.08002e-08
# 1    QuestionCreateDate  -9.3658e-09
# 11       QuestionLength  -6.0991e-05
# 12   QuestionCodeLength  -0.00166233
# 8              HasTried  -0.00190886
# 6          HasHyperlink   -0.0590464
# 7         HasEmbedImage   -0.0590464
# 2              HasError   -0.0731696
# 3          HasTraceback    -0.075378
# 9               NumTags    -0.104537
