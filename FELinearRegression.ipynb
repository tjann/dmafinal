# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (11.7, 11.3)
plt.rcParams.update({'font.size': 20})
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.3)})
from datetime import datetime
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import time

# %%
Questions = pd.read_csv('FEQuestions.csv')

# %%
Questions.head(2)
# Out:
#    QID  QuestionUserId    QuestionCreateDate  QuestionScore  \
# 0  469           147.0  2008-08-02T15:11:16Z             21
# 1  502           147.0  2008-08-02T17:01:58Z             27
#
#                                        QuestionTitle  \
# 0  How can I find the full path to a font from it...
# 1            Get a preview JPEG of a PDF on Windows?
#
#                                         QuestionBody  NumAnswers  \
# 0  <p>I am using the Photoshop's javascript API t...         4.0
# 1  <p>I have a cross-platform (Python) applicatio...         3.0
#
#                                 QuestionTitleAndBody CodeText  \
# 0  How can I find the full path to a font from it...      NaN
# 1  Get a preview JPEG of a PDF on Windows? <p>I h...      NaN
#
#                                   TagFreeNonCodeText         ...          \
# 0  How can I find the full path to a font from it...         ...
# 1  Get a preview JPEG of a PDF on Windows? I have...         ...
#
#   HasHyperlink HasEmbedImage  HasTried  \
# 0        False         False     False
# 1         True         False     False
#
#                                       Tags  NumTags  HasTagsInTop49  \
# 0  ['python', 'osx', 'fonts', 'photoshop']        4            True
# 1    ['python', 'windows', 'image', 'pdf']        4            True
#
#    QuestionLength  QuestionCodeLength  QuestionTitleLength QuestionPercentCode
# 0             721                   2                   17            0.002766
# 1             367                   2                    9            0.005420
#
# [2 rows x 26 columns]

# %%
print(Questions.isnull().sum())
# Out:
# QID                                  0
# QuestionUserId                    6212
# QuestionCreateDate                   0
# QuestionScore                        0
# QuestionTitle                        0
# QuestionBody                         0
# NumAnswers                           0
# QuestionTitleAndBody                 0
# CodeText                        408555
# TagFreeNonCodeText                   0
# CodeTextLemmatized                   0
# TagFreeNonCodeTextLemmatized         0
# HasError                             0
# HasTraceback                         0
# HasMultiLineCode                     0
# HasBlockCode                         0
# HasHyperlink                         0
# HasEmbedImage                        0
# HasTried                             0
# Tags                                 0
# NumTags                              0
# HasTagsInTop49                       0
# QuestionLength                       0
# QuestionCodeLength                   0
# QuestionTitleLength                  0
# QuestionPercentCode                  0
# dtype: int64

# %%
Questions['QuestionUserId'].fillna(0.0, inplace=True)
Questions['QuestionCreateDate'] = pd.to_datetime(Questions['QuestionCreateDate'])

# %%
Y = Questions.set_index('QID')[['NumAnswers']]

# %%
Y.head()
# Out:
#      NumAnswers
# QID
# 469         4.0
# 502         3.0
# 535         7.0
# 594         3.0
# 683         8.0

# %%
Y.mode()
# Out:
#    NumAnswers
# 0         1.0

# %%
Y.mean()
# Out:
# NumAnswers    1.603453
# dtype: float64

# %%
Y.median()
# Out:
# NumAnswers    1.0
# dtype: float64

# %%
r2_score(Y.NumAnswers, np.repeat(1, Y.shape[0]))
# Out:
# -0.1915525288536437

# %%
r2_score(Y.NumAnswers, np.repeat(1.603453, Y.shape[0]))
# Out:
# -3.019806626980426e-14

# %% [markdown]
# This is the R^2 to beat.

# %%
X = Questions.set_index('QID').drop(['Tags', 'QuestionTitle', 'QuestionBody', 'QuestionScore', 'NumAnswers', 'QuestionTitleAndBody', 'CodeText', 'TagFreeNonCodeText', 'CodeTextLemmatized', 'TagFreeNonCodeTextLemmatized'], axis=1, inplace=False)

# %%
X.head()
# Out:
#      QuestionUserId  QuestionCreateDate  HasError  HasTraceback  \
# QID
# 469           147.0 2008-08-02 15:11:16     False         False
# 502           147.0 2008-08-02 17:01:58     False         False
# 535           154.0 2008-08-02 18:43:54     False         False
# 594           116.0 2008-08-03 01:15:08     False         False
# 683           199.0 2008-08-03 13:19:16     False         False
#
#      HasMultiLineCode  HasBlockCode  HasHyperlink  HasEmbedImage  HasTried  \
# QID
# 469             False         False         False          False     False
# 502             False         False          True          False     False
# 535             False         False         False          False     False
# 594             False         False         False          False     False
# 683             False          True         False          False     False
#
#      NumTags  HasTagsInTop49  QuestionLength  QuestionCodeLength  \
# QID
# 469        4            True             721                   2
# 502        4            True             367                   2
# 535        3           False             963                   2
# 594        5           False             201                   2
# 683        3            True             422                  78
#
#      QuestionTitleLength  QuestionPercentCode
# QID
# 469                   17             0.002766
# 502                    9             0.005420
# 535                    7             0.002073
# 594                    9             0.009852
# 683                   12             0.156000

# %%
X.columns
# Out:
# Index(['QuestionUserId', 'QuestionCreateDate', 'HasError', 'HasTraceback',
#        'HasMultiLineCode', 'HasBlockCode', 'HasHyperlink', 'HasEmbedImage',
#        'HasTried', 'NumTags', 'HasTagsInTop49', 'QuestionLength',
#        'QuestionCodeLength', 'QuestionTitleLength', 'QuestionPercentCode'],
#       dtype='object')

# %% [markdown]
# Create 1-hot encoding for cyclic variables.

# %%
X['QuestionCreateDay'] = X['QuestionCreateDate'].dt.day

# %%
X['QuestionCreateMonth'] = X['QuestionCreateDate'].dt.month

# %%
X['QuestionCreateYear'] = X['QuestionCreateDate'].dt.year

# %%
X['QuestionCreateDayOfWeek'] = X['QuestionCreateDate'].dt.dayofweek

# %%
X['QuestionCreateHourOfDay'] = X['QuestionCreateDate'].dt.hour

# %%
X.columns
# Out:
# Index(['QuestionUserId', 'QuestionCreateDate', 'HasError', 'HasTraceback',
#        'HasMultiLineCode', 'HasBlockCode', 'HasHyperlink', 'HasEmbedImage',
#        'HasTried', 'NumTags', 'HasTagsInTop49', 'QuestionLength',
#        'QuestionCodeLength', 'QuestionTitleLength', 'QuestionPercentCode',
#        'QuestionCreateDay', 'QuestionCreateMonth', 'QuestionCreateYear',
#        'QuestionCreateDayOfWeek', 'QuestionCreateHourOfDay'],
#       dtype='object')

# %%
X_dummies = pd.get_dummies(X, columns=['QuestionCreateMonth', 'QuestionCreateDay', 'QuestionCreateDayOfWeek', 'QuestionCreateHourOfDay']).drop('QuestionCreateDate', axis=1)

# %%
X_dummies.head()
# Out:
#      QuestionUserId  HasError  HasTraceback  HasMultiLineCode  HasBlockCode  \
# QID
# 469           147.0     False         False             False         False
# 502           147.0     False         False             False         False
# 535           154.0     False         False             False         False
# 594           116.0     False         False             False         False
# 683           199.0     False         False             False          True
#
#      HasHyperlink  HasEmbedImage  HasTried  NumTags  HasTagsInTop49  \
# QID
# 469         False          False     False        4            True
# 502          True          False     False        4            True
# 535         False          False     False        3           False
# 594         False          False     False        5           False
# 683         False          False     False        3            True
#
#                 ...              QuestionCreateHourOfDay_14  \
# QID             ...
# 469             ...                                       0
# 502             ...                                       0
# 535             ...                                       0
# 594             ...                                       0
# 683             ...                                       0
#
#      QuestionCreateHourOfDay_15  QuestionCreateHourOfDay_16  \
# QID
# 469                           1                           0
# 502                           0                           0
# 535                           0                           0
# 594                           0                           0
# 683                           0                           0
#
#      QuestionCreateHourOfDay_17  QuestionCreateHourOfDay_18  \
# QID
# 469                           0                           0
# 502                           1                           0
# 535                           0                           1
# 594                           0                           0
# 683                           0                           0
#
#      QuestionCreateHourOfDay_19  QuestionCreateHourOfDay_20  \
# QID
# 469                           0                           0
# 502                           0                           0
# 535                           0                           0
# 594                           0                           0
# 683                           0                           0
#
#      QuestionCreateHourOfDay_21  QuestionCreateHourOfDay_22  \
# QID
# 469                           0                           0
# 502                           0                           0
# 535                           0                           0
# 594                           0                           0
# 683                           0                           0
#
#      QuestionCreateHourOfDay_23
# QID
# 469                           0
# 502                           0
# 535                           0
# 594                           0
# 683                           0
#
# [5 rows x 89 columns]

# %%
def adj_r2(r2, X):
    n = X.shape[0]
    p = X.shape[1]
    return 1 - (1 - r2) * ((n-1) / (n-p-1))

# %%
model = LinearRegression()
model.fit(X_dummies, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
training_accuracy_dummies = model.score(X_dummies, Y)
print("Training R^2: ", training_accuracy_dummies)
print("Training Adjusted R^2: ", adj_r2(training_accuracy_dummies, X_dummies))
# Out:
# Training R^2:  0.13856718073266983
# Training Adjusted R^2:  0.1384409150359629

# %%
pd.options.display.max_rows = 999

# %%
coeffs = pd.DataFrame(data=[X_dummies.columns, model.coef_.squeeze()]).T
coeffs.columns = ['Feature', 'Coeff']
coeffs.sort_values('Coeff', ascending=False)
# Out:
#                        Feature        Coeff
# 29         QuestionCreateDay_3      42128.3
# 43        QuestionCreateDay_17      42128.3
# 27         QuestionCreateDay_1      42128.3
# 38        QuestionCreateDay_12      42128.3
# 36        QuestionCreateDay_10      42128.3
# 39        QuestionCreateDay_13      42128.3
# 41        QuestionCreateDay_15      42128.3
# 37        QuestionCreateDay_11      42128.3
# 34         QuestionCreateDay_8      42128.3
# 49        QuestionCreateDay_23      42128.3
# 54        QuestionCreateDay_28      42128.3
# 56        QuestionCreateDay_30      42128.3
# 42        QuestionCreateDay_16      42128.3
# 33         QuestionCreateDay_7      42128.3
# 28         QuestionCreateDay_2      42128.3
# 32         QuestionCreateDay_6      42128.3
# 45        QuestionCreateDay_19      42128.3
# 51        QuestionCreateDay_25      42128.3
# 35         QuestionCreateDay_9      42128.3
# 57        QuestionCreateDay_31      42128.3
# 48        QuestionCreateDay_22      42128.3
# 31         QuestionCreateDay_5      42128.3
# 30         QuestionCreateDay_4      42128.3
# 44        QuestionCreateDay_18      42128.3
# 52        QuestionCreateDay_26      42128.3
# 47        QuestionCreateDay_21      42128.3
# 50        QuestionCreateDay_24      42128.3
# 40        QuestionCreateDay_14      42128.3
# 53        QuestionCreateDay_27      42128.3
# 55        QuestionCreateDay_29      42128.3
# 46        QuestionCreateDay_20      42128.3
# 13         QuestionPercentCode      2.92457
# 3             HasMultiLineCode     0.122038
# 9               HasTagsInTop49    0.0866328
# 4                 HasBlockCode    0.0738263
# 12         QuestionTitleLength     0.010877
# 7                     HasTried    0.0027133
# 0               QuestionUserId  5.90692e-08
# 10              QuestionLength -5.89336e-05
# 11          QuestionCodeLength  -0.00158427
# 1                     HasError   -0.0715521
# 2                 HasTraceback   -0.0737484
# 5                 HasHyperlink   -0.0830026
# 6                HasEmbedImage   -0.0857369
# 8                      NumTags    -0.101719
# 14          QuestionCreateYear    -0.293722
# 15       QuestionCreateMonth_1      -115965
# 16       QuestionCreateMonth_2      -115965
# 17       QuestionCreateMonth_3      -115965
# 18       QuestionCreateMonth_4      -115965
# 19       QuestionCreateMonth_5      -115965
# 20       QuestionCreateMonth_6      -115965
# 21       QuestionCreateMonth_7      -115965
# 22       QuestionCreateMonth_8      -115965
# 23       QuestionCreateMonth_9      -115965
# 24      QuestionCreateMonth_10      -115965
# 25      QuestionCreateMonth_11      -115965
# 26      QuestionCreateMonth_12      -115965
# 65   QuestionCreateHourOfDay_0      -116303
# 69   QuestionCreateHourOfDay_4      -116303
# 84  QuestionCreateHourOfDay_19      -116303
# 88  QuestionCreateHourOfDay_23      -116303
# 86  QuestionCreateHourOfDay_21      -116303
# 70   QuestionCreateHourOfDay_5      -116303
# 83  QuestionCreateHourOfDay_18      -116303
# 85  QuestionCreateHourOfDay_20      -116303
# 71   QuestionCreateHourOfDay_6      -116303
# 67   QuestionCreateHourOfDay_2      -116303
# 87  QuestionCreateHourOfDay_22      -116303
# 82  QuestionCreateHourOfDay_17      -116303
# 66   QuestionCreateHourOfDay_1      -116303
# 68   QuestionCreateHourOfDay_3      -116303
# 78  QuestionCreateHourOfDay_13      -116303
# 72   QuestionCreateHourOfDay_7      -116303
# 79  QuestionCreateHourOfDay_14      -116303
# 77  QuestionCreateHourOfDay_12      -116303
# 80  QuestionCreateHourOfDay_15      -116303
# 81  QuestionCreateHourOfDay_16      -116303
# 73   QuestionCreateHourOfDay_8      -116303
# 76  QuestionCreateHourOfDay_11      -116303
# 74   QuestionCreateHourOfDay_9      -116303
# 75  QuestionCreateHourOfDay_10      -116303
# 62   QuestionCreateDayOfWeek_4      -271985
# 61   QuestionCreateDayOfWeek_3      -271985
# 59   QuestionCreateDayOfWeek_1      -271985
# 60   QuestionCreateDayOfWeek_2      -271985
# 64   QuestionCreateDayOfWeek_6      -271985
# 58   QuestionCreateDayOfWeek_0      -271985
# 63   QuestionCreateDayOfWeek_5      -271985

# %% [markdown]
# Based on these coefficients, none of the time features make much of an impact.

# %%
X_nodummy = Questions.set_index('QID').drop(['Tags', 'QuestionTitle', 'QuestionBody', 'QuestionScore', 'NumAnswers', 'QuestionTitleAndBody', 'CodeText', 'TagFreeNonCodeText', 'CodeTextLemmatized', 'TagFreeNonCodeTextLemmatized'], axis=1, inplace=False)

# %%
X_nodummy['QuestionCreateDate'] = X_nodummy['QuestionCreateDate'].apply(lambda x: (x-datetime(1970,1,1)).total_seconds())

# %%
model_nodummy = LinearRegression()
model_nodummy.fit(X_nodummy, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
training_accuracy_nodummies = model_nodummy.score(X_nodummy, Y)
print("Training R^2: ", training_accuracy_nodummies)
print("Training Adjusted R^2: ", adj_r2(training_accuracy_nodummies, X_nodummy))
# Out:
# Training R^2:  0.138072905748014
# Training Adjusted R^2:  0.13805161539681077

# %%
coeffs = pd.DataFrame(data=[X_nodummy.columns, model_nodummy.coef_.squeeze()]).T
coeffs.columns = ['Feature', 'Coeff']
coeffs.sort_values('Coeff', ascending=False)
# Out:
#                 Feature        Coeff
# 14  QuestionPercentCode      2.90633
# 4      HasMultiLineCode     0.121801
# 10       HasTagsInTop49    0.0866519
# 5          HasBlockCode    0.0740014
# 13  QuestionTitleLength     0.011008
# 8              HasTried   0.00245624
# 0        QuestionUserId  5.90461e-08
# 1    QuestionCreateDate -9.31087e-09
# 11       QuestionLength  -5.8752e-05
# 12   QuestionCodeLength  -0.00157708
# 2              HasError   -0.0715647
# 3          HasTraceback   -0.0739976
# 6          HasHyperlink   -0.0828815
# 7         HasEmbedImage   -0.0864928
# 9               NumTags    -0.101848
